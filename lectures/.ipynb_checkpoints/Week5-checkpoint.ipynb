# %% [markdown]
# # Overview
#
# This week we'll talk about advanced network measures (beyond the degree distribution). We will use these tools to make sense of the Rapper network.
# This is the outline for today:
#
# * Visualization and qualitative analysis of the Rapper Network
# * Properties of the network structure, including how attributes and other properties shape the network
#
# > _Reading_: This week, the reading is mostly for reference. It's for you to have a place to go, if you want more detailed information about the topics that I cover in the video lectures. Thus, I recommend you check out **Chapter 9** of the network science book. In particular, we'll delve into [Section 9.4](http://networksciencebook.com/chapter/9#modularity) in the exercises below. We will also talk a little bit about degree correlations - you can read about those in [Chapter 7](http://networksciencebook.com/chapter/7)\.
#
#
# ![Text](https://wallpapers.com/images/high/cool-rapper-zs7xat10uqylszmy.webp "Great image choice, Jonas")

# %% [markdown]
# ---
# # Part A: Let's  visualise!

# %% [markdown]
# We will continue to work with the network from last week, see the lecture for [Week 4](https://nbviewer.jupyter.org/github/socialcomplexitylab/socialgraphs2021/blob/main/lectures/Week4.ipynb) for details. This is important! Actually, in order to continue with the lecture, you *need* to complete Week 4.
#
#
# *Exercise 1:* Build the right graph for visualization:
#
# >1. Use NetworkX `DiGraph` to store the network of rappers. Remember that rappers are linked if they have a corresponding link between their Wiki contents.
# >   * **Additionally**, extract the largest component - it will make our work with visualizations much easier (note: removing *isolated* nodes (with no links) does not guarantee that you are left with the largest component).
# >     - *Note 1*: You probably have the right graph if you have around 730 nodes and 6000 edges.
# >     - *Note 2*: For directed graphs use `weakly connected component` to extract the largest component.
# >     - *Note 3*: Further analysis is done with the largest component
# >2. As you build the graph, store the attributes of the nodes (their `coast`). On top of that, let's also store the `length of the content` as one of the attributes of the node (i.e. count the number of *words* you have in each rapper's page). By storing this information as nodal features, we keep all the relevant data in one place. The safe way to count words without counting symbols is to use `regex`, but simpler methods are OK.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import requests
import networkx as nx
import statistics

west = pd.read_csv('WestCoastRappers.csv')
east = pd.read_csv('EastCoastRappers.csv')
all_rappers = pd.concat([west, east])

west_names = west["WikipediaPageName"]
east_names = east["WikipediaPageName"]
all_names = all_rappers["WikipediaPageName"]

# %%
# Graph of rappers network
baseurl = "http://en.wikipedia.org/w/api.php?"
G = nx.DiGraph()
G.add_nodes_from(west_names, coast = 'West')
G.add_nodes_from(east_names, coast = 'East')
c = 0
for rapper in all_names:
    c += 1
    if c%100 == 0:
        print(c)
    params = {
    "action": "query",
    "prop": "revisions",
    "rvprop": "content",
    "format": "json",
    "titles": rapper
     }
    wikitext = requests.get(baseurl, params = params)
    wikijson = wikitext.json()
    num = list(wikijson['query']['pages'].keys())[0]
    text = wikijson['query']['pages'][num]['revisions'][0]['*']
    G.nodes[rapper]["count"] = len(re.findall(r"[\w']+", text)) #len(text.split())
    links = re.findall(r"\[\[(.*?)\]\]", text)
    true_links = [link.split('|')[0] for link in links] 
    names = all_rappers[all_rappers["WikipediaPageName"].isin(true_links)]["WikipediaPageName"]
    for name in names:
        G.add_edge(rapper, name)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800

# %%
# Find largest connected component
largest_cc = G.subgraph(max(nx.weakly_connected_components(G), key=len))
print('Number of nodes in largest cc: ', largest_cc.number_of_nodes())
print('Number of edges in largest cc: ', largest_cc.size())
# Out:
# Number of nodes in largest cc:  728
# Number of edges in largest cc:  5809

# %%
#test = sorted(nx.get_node_attributes(G, "count").items(), key=lambda x:x[1])

# %% [markdown]
# *Exercise 2:* Let's build a simple visualization of the network
# >1. For the sake of the visualisation, let's convert our network to *undirected graph* (tip: There is a NetworkX command to help you).
# >   * *Note*: Keep the directed graph, we will use it in couple of the following exercises
# >2. Use the NetworkX command `nx.draw_kamada_kawai` to draw the resulting undirected network. (You can find [background on the algorithm here](https://en.wikipedia.org/wiki/Force-directed_graph_drawing).)
# >   * Node color should depend on the `coast` attribute (i.e. use different colors for west-coast and east-coast rappers).
# >   * Set up your plot so that node-size depends on the node *degree*
# >   * **Optional**: Set up you plot so that edge color depends on the `role` attribute. If an edge connects west-coast rappers, assign `color_a`, if the edge connects east-coast rappers assign `color_b`, in other cases assign `color_c` (i.e. when rapper from different coasts are connected). (Here, you get to decide on the colors.)

# %%
pos = nx.kamada_kawai_layout(G_un)

# %%
#Convert to undirected
G_un = largest_cc.to_undirected()

west_names_largest_cc = list(set(west_names) & set(list(G_un.nodes)))
east_names_largest_cc = list(set(east_names) & set(list(G_un.nodes)))
west_node_sizes = [G_un.nodes[rapper]["count"]/1000 for rapper in west_names_largest_cc]
east_node_sizes = [G_un.nodes[rapper]["count"]/1000 for rapper in east_names_largest_cc]

edge_colors = []
for i,j in G_un.edges():
    if i in east_names_largest_cc and j in east_names_largest_cc:
        edge_colors.append('blue')
    elif i in west_names_largest_cc and j in west_names_largest_cc:
        edge_colors.append('red')
    else:
        edge_colors.append('green')
                       
W = largest_cc.subgraph(west_names_largest_cc)
E = largest_cc.subgraph(east_names_largest_cc)

# %%
#Plot graph  
#nx.draw_kamada_kawai(G_un)
plt.rcParams['figure.figsize'] = [10,10]
nx.draw_networkx_nodes(W, pos, node_size = [d/2 for r,d in W.degree()], nodelist=west_names_largest_cc, node_color="tab:red")
nx.draw_networkx_nodes(E, pos, node_size = [d/2 for r,d in E.degree()], nodelist=east_names_largest_cc, node_color="tab:blue")
nx.draw_networkx_edges(G_un, pos, edge_color = edge_colors)
plt.show()

# %% [markdown]
# *Exercise 3:* From the previous plot it is more difficult to observe any specific structure in the network. We can make even better visualisations with `ForceAtlas2` package:
# >1. [Force Atlas 2 algorithm](https://github.com/bhargavchippada/forceatlas2) helps to determine the positions of the nodes (see what the result looks like below).
# >2.You can install the  package typing `pip install fa2` in the terminal. The [github page](https://github.com/bhargavchippada/forceatlas2) explains how to use the package to get coordinates for each node.
# >   * (**Hint**: if you install force atlas and Python can't find the package it might be because you computer tries to use the system's `pip`, therefore, try installing using the Anaconda pip explicitly ( on mac you would use `~/anaconda2/bin/pip install fa2`).
# > * Visualize the network using the [Networkx draw function](https://networkx.github.io/documentation/stable/reference/generated/networkx.drawing.nx_pylab.draw.html#networkx.drawing.nx_pylab.draw), and node-coordinates from the force atlas algorithm. As in the previous Exercise:
# >   * Node color should depend on the `coast` attribute (i.e. use different colors for west-coast and east-coast rappers)
# >   * Node size should depend on the node *degree*
# >   * **Optional**: edge color should depend on the `coast` attribute. If an edge connects west-coast rappers, assign `color_a`, if the edge connects east-coast rappers from  assign `color_b`, in other cases assign `color_c` (i.e. when connected rappers are from different coasts).
# > * Play with the force atlas algorithm parameters to obtain a visualization you like. It may look similar to the one below (but not necessarily).
# > * Describe the structure you observe. Can you identify nodes with a privileged position in the network? Do you observe chains of connected nodes? Do you see any interesting group of nodes (can you guess who's involved)?

# %% [markdown]
# ![Text]()

# %% [markdown]
# ![](https://github.com/SocialComplexityLab/socialgraphs2023/blob/main/files/Visualfa2Rappers.pngraw=true)

# %% [markdown]
# *Exercise 4*: We continue with a qualitative inspection of the rapper Wiki pages, that will help us to intepret our results. We investigate the reasons for links between rappers to exist on rapper Wiki.
#
# >1. Consider the top 3 nodes with highest in-degree in the network. Open the corresponding Wiki pages.
# >   * Consider the set of neighbours pointing towards the node found above. Look for them in the page.
# >   * What is the relation between the rappers you identified and his/her network neighbours? (e.g., do they come from the same coast, did they write songs together, etc.). You don't need to come up with a grand theory of rap music here, I just want you to think about how links come about.
#
# If they make music together, if they are related (family), if they are inspired by, if the have the same producer
#
# >   * Repeat the exercise for the top 3 out-degree node.
# >   * Are there differences between reasons for out- and in-links? Again, there's no right answer here. I just want you to think about some of the reasons why links may occur between rappers.
#
# Out degree is determined mostly by guest-apperances and whether or not they have produced music for other artists. (The producers)
#
# >2. Are there any nodes with high out-degree and with few incoming connections? If yes, open the Wiki pages of such rappers and explain what happens?
# >3. Are there any nodes with high in-degree and few outcoming connections? Again, open the Wiki pages of such rappers and explain what happens?
# >4. Do any nodes have particularly many links to rappers from the opposite coast? If yes, try and find out what is going on.

# %%
# Top 3 rappers (in-degree)
in_degree_sequence = [(d,n) for d,n in largest_cc.in_degree()]
in_degree_sequence.sort(key=lambda x: x[1], reverse=True)
print('Top 3 connected rappers (In degree): ', in_degree_sequence[:3])

Snoop_pre = list(largest_cc.predecessors('Snoop Dogg'))
Jayz_pre = list(largest_cc.predecessors('Jay-Z'))
Nas_pre = list(largest_cc.predecessors('Nas'))

# Top 3 rappers (out-degree)
# Top 3 rappers (in-degree)
out_degree_sequence = [(d,n) for d,n in largest_cc.out_degree()]
out_degree_sequence.sort(key=lambda x: x[1], reverse=True)
print('Top 3 connected rappers (Out degree): ', out_degree_sequence[:3])

#list(largest_cc.successors('Drag-On'))

highout_lowin = [(d_out, n) if largest_cc.in_degree(n) <= 10 else (0, n) for (n,d_out) in largest_cc.out_degree()]
highout_lowin.sort(key=lambda x: x[0], reverse=True)
#highout_lowin

highin_lowout = [(d_in, n) if largest_cc.out_degree(n) <= 10 else (0, n) for (n,d_in) in largest_cc.in_degree()]
highin_lowout.sort(key=lambda x: x[0], reverse=True)
#highin_lowout

my_dict = {rapper:0 for rapper in largest_cc.nodes()}
for i,j in largest_cc.edges():
    if i in east_names_largest_cc and j in west_names_largest_cc:
        my_dict[i] += 1
    elif i in west_names_largest_cc and j in east_names_largest_cc:
        my_dict[i] += 1

test = sorted(my_dict.items(), key = lambda x:x[1], reverse=True)
test
# Out:
# Top 3 connected rappers (In degree):  [('Snoop Dogg', 127), ('Jay-Z', 114), ('Nas', 98)]
# Top 3 connected rappers (Out degree):  [('Drag-On', 52), ('Black Thought', 42), ('DJ Dahi', 38)]
# [('The Game (rapper)', 20),
#  ('Kendrick Lamar', 20),
#  ('The Alchemist (musician)', 19),
#  ('Dr. Dre', 15),
#  ('Kurupt', 14),
#  ('Focus...', 14),
#  ('Tupac Shakur', 13),
#  ('Hit-Boy', 12),
#  ('Ras Kass', 11),
#  ('Cardiak', 11),
#  ('DJ Dahi', 10),
#  ('Knxwledge', 9),
#  ('DJ Quik', 9),
#  ('Ty Dolla Sign', 9),
#  ('Talib Kweli', 9),
#  ('French Montana', 9),
#  ('Lecrae', 8),
#  ('Oh No (musician)', 8),
#  ('Aone Beats', 8),
#  ('Black Thought', 8),
#  ('Andy Mineo', 8),
#  ('Crooked I', 7),
#  ('Snoop Dogg', 7),
#  ('Ice-T', 7),
#  ('Kam (rapper)', 7),
#  ('Kid Ink', 7),
#  ('Madlib', 7),
#  ('Slim the Mobster', 7),
#  ('Schoolboy Q', 7),
#  ('Tyler, the Creator', 7),
#  ('Jahlil Beats', 7),
#  ('Wiz Khalifa', 7),
#  ('Mac Miller', 7),
#  ('The Notorious B.I.G.', 7),
#  ('Silkski', 7),
#  ('Chris Webby', 7),
#  ('Ab-Soul', 6),
#  ('Coolio', 6),
#  ('Fashawn', 6),
#  ('Fatlip', 6),
#  ('Nipsey Hussle', 6),
#  ('Jake One', 6),
#  ('Macklemore', 6),
#  ('Spider Loc', 6),
#  ('Xzibit', 6),
#  ('YG (rapper)', 6),
#  ('50 Cent', 6),
#  ('Tim Dog', 6),
#  ('E.D.I. Mean', 6),
#  ('Freddie Foxxx', 6),
#  ('Jay-Z', 6),
#  ('MC Lyte', 6),
#  ('Megahertz (record producer)', 6),
#  ('Nas', 6),
#  ('Roscoe (rapper)', 6),
#  ('Sha Money XL', 6),
#  ('Mike Zombie', 6),
#  ('Bizzle', 5),
#  ('Blueface', 5),
#  ('Buddy (rapper)', 5),
#  ('Sway Calloway', 5),
#  ('Scoop DeVille', 5),
#  ('Dom Kennedy', 5),
#  ('Bishop Lamont', 5),
#  ('Locksmith (rapper)', 5),
#  ('Brother Marquis', 5),
#  ('Terrace Martin', 5),
#  ('Lil Mosey', 5),
#  ('Too Short', 5),
#  ('Big Daddy Kane', 5),
#  ('Action Bronson', 5),
#  ('Ceschi', 5),
#  ('Cordae', 5),
#  ('Dash (rapper)', 5),
#  ('Drag-On', 5),
#  ('Dave East', 5),
#  ('Jadakiss', 5),
#  ('Like (record producer)', 5),
#  ('Joell Ortiz', 5),
#  ('Prince Paul (producer)', 5),
#  ('DJ Premier', 5),
#  ('Vinylz', 5),
#  ('Chevy Woods', 5),
#  ('Wyldfyer', 5),
#  ('MC Eiht', 4),
#  ('Mike Free', 4),
#  ('O.T. Genasis', 4),
#  ('Domo Genesis', 4),
#  ('Sir Jinx', 4),
#  ('Mr. J. Medeiros', 4),
#  ('Mix Master Mike', 4),
#  ('Jay Park', 4),
#  ('Quazedelic', 4),
#  ('Mike Shinoda', 4),
#  ('Snow Tha Product', 4),
#  ('Vince Staples', 4),
#  ('Earl Sweatshirt', 4),
#  ('Big Syke', 4),
#  ('Big Body Bes', 4),
#  ('Call Me Ace', 4),
#  ('John Cena', 4),
#  ('DJ Drama', 4),
#  ('Inspectah Deck', 4),
#  ('Ja Rule', 4),
#  ('MC Jin', 4),
#  ('JPEGMafia', 4),
#  ('Trip Lee', 4),
#  ('Lil Peep', 4),
#  ('Mach-Hommy', 4),
#  ('Roc Marciano', 4),
#  ('Method Man', 4),
#  ('Bishop Nehru', 4),
#  ('Prodigy (rapper)', 4),
#  ('Busta Rhymes', 4),
#  ('Bobby Shmurda', 4),
#  ('24kGoldn', 3),
#  ('B-Legit', 3),
#  ('Ant Banks', 3),
#  ('Berner (rapper)', 3),
#  ('Big Dave (rapper)', 3),
#  ('Busdriver', 3),
#  ('Clyde Carson', 3),
#  ('Conceit (rapper)', 3),
#  ('Cut Chemist', 3),
#  ('Demrick', 3),
#  ('Nate Dogg', 3),
#  ('Exile (producer)', 3),
#  ('Flying Lotus', 3),
#  ('Jel (music producer)', 3),
#  ('MC Lars', 3),
#  ('Mr. Mixx', 3),
#  ('Myka 9', 3),
#  ('Damani Nkosi', 3),
#  ('Problem (rapper)', 3),
#  ('RBX', 3),
#  ('Shade Sheist', 3),
#  ('Skeme', 3),
#  ('Skinhead Rob', 3),
#  ('Time (rapper)', 3),
#  ('Casey Veggies', 3),
#  ('Willie B (producer)', 3),
#  ('Yo-Yo (rapper)', 3),
#  ('Yukmouth', 3),
#  ('Apathy (rapper)', 3),
#  ('M. K. Asante', 3),
#  ('DJ Babu', 3),
#  ('Benny the Butcher', 3),
#  ('Foxy Brown (rapper)', 3),
#  ('Canibus', 3),
#  ('Kid Capri', 3),
#  ('DMX', 3),
#  ('Smoke DZA', 3),
#  ('Fabolous', 3),
#  ('Harry Fraud', 3),
#  ('Ty Fyffe', 3),
#  ('Cory Gunz', 3),
#  ('Jaz-O', 3),
#  ('Joey Badass', 3),
#  ('DJ Kay Slay', 3),
#  ('Kool Moe Dee', 3),
#  ('Al Sherrod Lambert', 3),
#  ('Joyner Lucas', 3),
#  ('Biz Markie', 3),
#  ("Mr. Muthafuckin' eXquire", 3),
#  ('Easy Mo Bee', 3),
#  ('Uncle Murda', 3),
#  ('No Malice', 3),
#  ('Percee P', 3),
#  ('Jamal Phillips', 3),
#  ('Pusha T', 3),
#  ('Salaam Remi', 3),
#  ('ASAP Rocky', 3),
#  ('Sauce Money', 3),
#  ('DJ Skee', 3),
#  ('Sho Baraka', 2),
#  ('Becky G', 2),
#  ('Big Fase 100', 2),
#  ('Nissim Black', 2),
#  ('Toni Blackman', 2),
#  ('Nick Cannon', 2),
#  ('Chanel West Coast', 2),
#  ('Cozz', 2),
#  ('The D.O.C.', 2),
#  ('Timothy DeLaGhetto', 2),
#  ('Domino (rapper)', 2),
#  ('Drakeo the Ruler', 2),
#  ('Joey Fatts', 2),
#  ('JT the Bigga Figga', 2),
#  ('Fresh Kid Ice', 2),
#  ('Futuristic (rapper)', 2),
#  ('The Futuristics', 2),
#  ('Grieves', 2),
#  ('Hopsin', 2),
#  ('Iamsu!', 2),
#  ('Jeff Jericho', 2),
#  ('DJ Khalil', 2),
#  ('King T', 2),
#  ('Kokane', 2),
#  ('Lefty (rapper)', 2),
#  ('Lil Xan', 2),
#  ('LoveRance', 2),
#  ('Mac Mall', 2),
#  ('Mann (rapper)', 2),
#  ('Messy Marv', 2),
#  ('Jonathan Moore (musician)', 2),
#  ('Passion (rapper)', 2),
#  ('Red Cloud (rapper)', 2),
#  ('Boots Riley', 2),
#  ('Sadistik', 2),
#  ('Amanda Seales', 2),
#  ('Sky Blu (rapper)', 2),
#  ('Sleep (rapper)', 2),
#  ('Slimkid3', 2),
#  ('Smooth (singer)', 2),
#  ('TeeFlii', 2),
#  ('6ix9ine', 2),
#  ('AraabMuzik', 2),
#  ('Lloyd Banks', 2),
#  ('Mark Batson', 2),
#  ('The Beat Bully', 2),
#  ('Blockhead (music producer)', 2),
#  ('Buckwild (music producer)', 2),
#  ('Joe Budden', 2),
#  ('Don Cannon', 2),
#  ('Capital Steez', 2),
#  ('Cardi B', 2),
#  ('Casanova (rapper)', 2),
#  ("Lil' Cease", 2),
#  ('Chyskillz', 2),
#  ('Clams Casino (musician)', 2),
#  ('Sean Combs', 2),
#  ('Cousin Stizz', 2),
#  ('Kosha Dillz', 2),
#  ('MF Doom', 2),
#  ('Ed O.G.', 2),
#  ('El-P', 2),
#  ('Eve (rapper)', 2),
#  ('Funkmaster Flex', 2),
#  ('G Koop', 2),
#  ('Jean Grae', 2),
#  ('Dame Grease', 2),
#  ('Charles Hamilton (rapper)', 2),
#  ('Samuel T. Herring', 2),
#  ('DJ Hurricane', 2),
#  ('J57 (rapper)', 2),
#  ('Kool G Rap', 2),
#  ('Lee on the Beats', 2),
#  ('Lil Dicky', 2),
#  ('Lil Tjay', 2),
#  ("Lil' Kim", 2),
#  ('M-Dot', 2),
#  ('Meek Mill', 2),
#  ('Mims (rapper)', 2),
#  ('Mos Def', 2),
#  ('Young Noble', 2),
#  ('O.C. (rapper)', 2),
#  ('Queen Latifah', 2),
#  ('Queen Pen', 2),
#  ('Rakim', 2),
#  ('Hell Razah', 2),
#  ('Red Café', 2),
#  ('Sadat X', 2),
#  ('Saga (rapper)', 2),
#  ('Shock G', 2),
#  ('Kiing Shooter', 2),
#  ('David Stones', 2),
#  ('Swizz Beatz', 2),
#  ('Treach', 2),
#  ('Tierra Whack', 2),
#  ('40 Glocc', 1),
#  ('Aceyalone', 1),
#  ('Afroman', 1),
#  ('Antwon', 1),
#  ('Guerilla Black', 1),
#  ('Blxst', 1),
#  ('Bones (rapper)', 1),
#  ('Braille (musician)', 1),
#  ('Celestaphone', 1),
#  ('Shawn Chrystopher', 1),
#  ('Dazzie Dee', 1),
#  ('Del the Funky Homosapien', 1),
#  ('Daz Dillinger', 1),
#  ('Droop-E', 1),
#  ('Dumbfoundead', 1),
#  ('Eazy-E', 1),
#  ('Eprhyme', 1),
#  ('Evidence (musician)', 1),
#  ('Kevin Federline', 1),
#  ('DJ Fresh (American DJ)', 1),
#  ('GaTa', 1),
#  ('Hi-C (rapper)', 1),
#  ('Hot Rod (rapper)', 1),
#  ('Brotha Lynch Hung', 1),
#  ('Hurt-M-Badd', 1),
#  ('Skhye Hutch', 1),
#  ('Iame (rapper)', 1),
#  ('Ice Cube', 1),
#  ('ILoveMakonnen', 1),
#  ('Baby Keem', 1),
#  ('King Tech', 1),
#  ('Curtiss King', 1),
#  ('Kossisko', 1),
#  ('Kreayshawn', 1),
#  ('Krondon', 1),
#  ('Kyle (musician)', 1),
#  ('Shorty (American rapper)', 1),
#  ('Lil B', 1),
#  ('Lil Rob', 1),
#  ('CJ Mac', 1),
#  ('Glasses Malone', 1),
#  ('Trevor McFedries', 1),
#  ('Mr. Capone-E', 1),
#  ('Murs (rapper)', 1),
#  ('Emcee N.I.C.E.', 1),
#  ('Only Won', 1),
#  ('Paris (rapper)', 1),
#  ('Captain Rapp', 1),
#  ('Reason (American rapper)', 1),
#  ('Ash Riser', 1),
#  ('RJ (rapper)', 1),
#  ('Jay Rock', 1),
#  ('V. Rose', 1),
#  ('Saweetie', 1),
#  ('Dom Sicily', 1),
#  ('Slip Capone', 1),
#  ('Soopafly', 1),
#  ('Sounwave', 1),
#  ('Rob Stone (rapper)', 1),
#  ('Syd (singer)', 1),
#  ('Tairrie B', 1),
#  ('Tanna Leone', 1),
#  ('Thurz', 1),
#  ('Ms. Toi', 1),
#  ('Isaiah Toothtaker', 1),
#  ('Channel Tres', 1),
#  ('MC Trouble', 1),
#  ('V-Nasty', 1),
#  ('Warren G', 1),
#  ('Dizzy Wright', 1),
#  ('Ya Boy', 1),
#  ('38 Spesh', 1),
#  ('Akrobatik', 1),
#  ('Hoodie Allen', 1),
#  ('Apache (rapper)', 1),
#  ('Arkatech Beatz', 1),
#  ('Awkwafina', 1),
#  ('AZ (rapper)', 1),
#  ('MC Paul Barman', 1),
#  ('Bronx Style Bob', 1),
#  ('Tommy Brown (record producer)', 1),
#  ('Buckshot (rapper)', 1),
#  ('Capella Grey', 1),
#  ('Capone (rapper)', 1),
#  ('Conway the Machine', 1),
#  ('Jay Critch', 1),
#  ('D-Nice', 1),
#  ('Diabolic (rapper)', 1),
#  ('Dot da Genius', 1),
#  ('East Flatbush Project', 1),
#  ('Fat Joe', 1),
#  ('Hussein Fatal', 1),
#  ('Felly', 1),
#  ('ASAP Ferg', 1),
#  ('CJ Fly', 1),
#  ('Fred the Godson', 1),
#  ('Frenchie (rapper)', 1),
#  ('Heather B. Gardner', 1),
#  ('Irv Gotti', 1),
#  ('MF Grimm', 1),
#  ('Havoc (musician)', 1),
#  ('Emile Haynie', 1),
#  ('Ill Bill', 1),
#  ('Jam Master Jay', 1),
#  ('Jasiri X', 1),
#  ('Serius Jones', 1),
#  ('Just Blaze', 1),
#  ('Kastro (rapper)', 1),
#  ('Kemba (rapper)', 1),
#  ('Big L', 1),
#  ('Le1f', 1),
#  ('Mr. Lif', 1),
#  ('Lil Mama', 1),
#  ('Ex-plicit linez', 1),
#  ('Nicholas Loftin', 1),
#  ('Marley Marl', 1),
#  ('Masta Killa', 1),
#  ('Darryl McDaniels', 1),
#  ('Melle Mel', 1),
#  ('Derrick Milano', 1),
#  ('Pharoahe Monch', 1),
#  ('Keith Murray', 1),
#  ('Myzery', 1),
#  ('N.O.R.E.', 1),
#  ('Necro (rapper)', 1),
#  ('Neo da Matrix', 1),
#  ("Shaquille O'Neal", 1),
#  ('Styles P', 1),
#  ('Felicia Pearson', 1),
#  ('Pete Rock', 1),
#  ('Phife Dawg', 1),
#  ('Stelios Phili', 1),
#  ('Phresher', 1),
#  ('Prince Whipper Whip', 1),
#  ('Princess Superstar', 1),
#  ('Pumpkinhead (rapper)', 1),
#  ('Q-Tip (musician)', 1),
#  ('Radamiz', 1),
#  ('Kyle Rapps', 1),
#  ('Chubb Rock', 1),
#  ('Rockwilder', 1),
#  ('David Rush (rapper)', 1),
#  ('RZA', 1),
#  ('Scar Lip', 1),
#  ('Schoolly D', 1),
#  ('Jill Scott (singer)', 1),
#  ('Sensato del Patio', 1),
#  ('Shyne', 1),
#  ('Siya', 1),
#  ('Rashad Smith (producer)', 1),
#  ('Sam Sneed', 1),
#  ('Busy Bee Starski', 1),
#  ('Statik Selektah', 1),
#  ('Yhaunai Takiyal', 1),
#  ('Teyana Taylor', 1),
#  ('Termanology', 1),
#  ('Token (rapper)', 1),
#  ('Justina Valentine', 1),
#  ('Fetty Wap', 1),
#  ('Westside Gunn', 1),
#  ('DJ Whoo Kid', 1),
#  ('Saul Williams', 1),
#  ('Wordsworth (rapper)', 1),
#  ('Tony Yayo', 1),
#  ('Young Chris', 1),
#  ('Young M.A', 1),
#  ('03 Greedo', 0),
#  ('DJ A-Tron', 0),
#  ('Abstract Rude', 0),
#  ('Ahmad (rapper)', 0),
#  ("Ak'Sent", 0),
#  ('AMG (rapper)', 0),
#  ('Aminé (rapper)', 0),
#  ('B-Real', 0),
#  ('B.G. Knocc Out', 0),
#  ('Show Banga', 0),
#  ('Beeda Weeda', 0),
#  ('Beefy (rapper)', 0),
#  ('Big B (rapper)', 0),
#  ('Big Ed (rapper)', 0),
#  ('Aloe Blacc', 0),
#  ('Scott Caan', 0),
#  ("Captain Save 'Em", 0),
#  ('DJ Cheapshot', 0),
#  ('Tha Chill', 0),
#  ('Omega Crosby', 0),
#  ('Daddy X', 0),
#  ('DB Tha General', 0),
#  ('Dubb 20', 0),
#  ('E-40', 0),
#  ('Flash Bang Grenada', 0),
#  ('Shawn Fonteno', 0),
#  ('Foreknown (rapper)', 0),
#  ('Dave Free', 0),
#  ('MC Frontalot', 0),
#  ('Frost (rapper)', 0),
#  ('G-Nut', 0),
#  ('G-Stack', 0),
#  ('Gift of Gab (rapper)', 0),
#  ("Haiku d'Etat", 0),
#  ('Hittman', 0),
#  ('Hodgy', 0),
#  ('Houston (singer)', 0),
#  ('The Jacka', 0),
#  ('Noa James', 0),
#  ('JGivens', 0),
#  ('JHawk', 0),
#  ('Hobo Johnson', 0),
#  ('Judge Da Boss', 0),
#  ('Self Jupiter', 0),
#  ('K-the-I???', 0),
#  ('Keak da Sneak', 0),
#  ('Killa Keise', 0),
#  ('DJ King Assassin', 0),
#  ('King Lil G', 0),
#  ('Rydah J. Klyde', 0),
#  ('Knightowl', 0),
#  ('Lil Debbie', 0),
#  ('Lil Italy', 0),
#  ('Lil Ric', 0),
#  ("Lil' C-Style", 0),
#  ('Luni Coleone', 0),
#  ('Mac Dre', 0),
#  ('Mack 10', 0),
#  ('Mayne Mannish', 0),
#  ('Young Maylay', 0),
#  ('Eli Meltzer', 0),
#  ('Cymphonique Miller', 0),
#  ('Mistah F.A.B.', 0),
#  ('Mr. Skrillz', 0),
#  ('Mugzi', 0),
#  ('Shady Nate', 0),
#  ('Nobody (producer)', 0),
#  ('Nocando', 0),
#  ('Cool Nutz', 0),
#  ('O.Y.G Redrum 781', 0),
#  ('OhGeesy', 0),
#  ('Peace (rapper)', 0),
#  ('J Peezy', 0),
#  ('Dudley Perkins (rapper)', 0),
#  ('Phil Da Agony', 0),
#  ('Playalitical', 0),
#  ('Pooh-Man', 0),
#  ('Psychosiz', 0),
#  ('Punch (rapper)', 0),
#  ('San Quinn', 0),
#  ("Rappin' 4-Tay", 0),
#  ('Redfoo', 0),
#  ('The Real Richie Rich', 0),
#  ('Sage the Gemini', 0),
#  ('Seagram (rapper)', 0),
#  ('Mac Shawn', 0),
#  ('Shorty Mack', 0),
#  ('Shwayze', 0),
#  ('Raz Simone', 0),
#  ('Sir Mix-a-Lot', 0),
#  ('Skee-Lo', 0),
#  ('Sleep Dank', 0),
#  ('Mitchy Slick', 0),
#  ('Slow Pain', 0),
#  ('Na-Kel Smith', 0),
#  ('D Smoke', 0),
#  ('Speak!', 0),
#  ('Spice 1', 0),
#  ('Parlay Starr', 0),
#  ('Stressmatic', 0),
#  ('Suga Free', 0),
#  ('Suga-T', 0),
#  ('Taboo (rapper)', 0),
#  ('Tedashii', 0),
#  ('Tiger JK', 0),
#  ('Tone Loc', 0),
#  ('The Unknown DJ', 0),
#  ('V-White', 0),
#  ('Bryce Vine', 0),
#  ('WC (rapper)', 0),
#  ('YGD Tha Top Dogg', 0),
#  ('Zealous1', 0),
#  ('Asaiah Ziv', 0),
#  ('9th Prince', 0),
#  ('22Gz', 0),
#  ('The 45 King', 0),
#  ('60 Second Assassin (rapper)', 0),
#  ('88-Keys', 0),
#  ('Sammy Adams', 0),
#  ('Adeem (rapper)', 0),
#  ('Aesop Rock', 0),
#  ('Afu-Ra', 0),
#  ('Akir', 0),
#  ('Alias (musician)', 0),
#  ('Amil', 0),
#  ('Antoinette (rapper)', 0),
#  ('AR-Ab', 0),
#  ('Asheru', 0),
#  ('The Audible Doctor', 0),
#  ('Apani B. Fly', 0),
#  ('Bahamadia', 0),
#  ('Marty Baller', 0),
#  ('Charli Baltimore', 0),
#  ('Afrika Bambaataa', 0),
#  ('Bodega Bamz', 0),
#  ('Azealia Banks', 0),
#  ('Beedie (rapper)', 0),
#  ('Benzino', 0),
#  ('Big Pun', 0),
#  ('Big Shug', 0),
#  ('Bkorn', 0),
#  ('Black Child', 0),
#  ('Black Rob', 0),
#  ('Memphis Bleek', 0),
#  ('Ron Browz', 0),
#  ('Dai Burger', 0),
#  ('Cage (rapper)', 0),
#  ('Crystal Caines', 0),
#  ("Cam'ron", 0),
#  ('Cappadonna', 0),
#  ('Cassidy (rapper)', 0),
#  ('Grandmaster Caz', 0),
#  ('Cazwell', 0),
#  ('DJ Charlie Chase', 0),
#  ('Chinx', 0),
#  ('DJ Chuck Chillout', 0),
#  ('CJ (rapper)', 0),
#  ('Consequence (rapper)', 0),
#  ('Cool C', 0),
#  ('Keef Cowboy', 0),
#  ('Cuban Link', 0),
#  ('Daddy-O (rapper)', 0),
#  ('Danger Mouse (musician)', 0),
#  ('Danny Boy (rapper)', 0),
#  ('Desiigner', 0),
#  ('Flipp Dinero', 0),
#  ('Disco King Mario', 0),
#  ('DJ Disco Wiz', 0),
#  ('B. Dolan', 0),
#  ('Don Q (rapper)', 0),
#  ('Dub-L', 0),
#  ('Dutch ReBelle', 0),
#  ('DVLP', 0),
#  ('Eric B.', 0),
#  ('Esoteric (rapper)', 0),
#  ('Eyenine', 0),
#  ('Mickey Factz', 0),
#  ('Grandmaster Flash', 0),
#  ('Fivio Foreign', 0),
#  ('Njena Reddd Foxxx', 0),
#  ('Sage Francis', 0),
#  ('Freekey Zekey', 0),
#  ('Doug E. Fresh', 0),
#  ('Mic Geronimo', 0),
#  ('Ghostface Killah', 0),
#  ('Godfather Don', 0),
#  ('Grafh', 0),
#  ('Guru (rapper)', 0),
#  ('GZA', 0),
#  ('Half a Mill', 0),
#  ('Sleepy Hallow', 0),
#  ('Andre Harrell', 0),
#  ('Heavy D', 0),
#  ('Hell Rell', 0),
#  ('Chad Hugo', 0),
#  ('Ice Spice', 0),
#  ('Islord', 0),
#  ('J.I the Prince of N.Y', 0),
#  ('Ms. Jade', 0),
#  ('Mike Jaggerr', 0),
#  ('MC Jazzy Jeff', 0),
#  ('DJ Jazzy Joyce', 0),
#  ('Jipsta', 0),
#  ('Chilla Jones', 0),
#  ('Junglepussy', 0),
#  ('Just-Ice', 0),
#  ('Killa Sin', 0),
#  ('Kirk Knight', 0),
#  ('Tate Kobang', 0),
#  ('KRS-One', 0),
#  ('Coke La Rock', 0),
#  ('Scott La Rock', 0),
#  ('Lady B', 0),
#  ('Lamiere', 0),
#  ('Knero Lapaé', 0),
#  ('Johan Lenox', 0),
#  ('Coi Leray', 0),
#  ('Alrad Lewis', 0),
#  ('Rob Lewis (record producer)', 0),
#  ('Lin Que', 0),
#  ('Dusty Locane', 0),
#  ('Sheek Louch', 0),
#  ('Louis Logic', 0),
#  ('Ed Lover', 0),
#  ('Jan Lucanus', 0),
#  ('Remy Ma', 0),
#  ('China Mac', 0),
#  ('Craig Mack', 0),
#  ('Malik B.', 0),
#  ('Skizzy Mars', 0),
#  ('Mase', 0),
#  ('Mathematics (producer)', 0),
#  ('Ivan Matias', 0),
#  ('Lady May (rapper)', 0),
#  ('McGruff (rapper)', 0),
#  ('Mikey D', 0),
#  ('Jae Millz', 0),
#  ('Ali Shaheed Muhammad', 0),
#  ('ASAP Nast', 0),
#  ('Nine (rapper)', 0),
#  ('NOE (rapper)', 0),
#  ('Princess Nokia', 0),
#  ("Ol' Dirty Bastard", 0),
#  ('Pepa (rapper)', 0),
#  ('Petey Pablo', 0),
#  ('Pras', 0),
#  ('Sean Price', 0),
#  ('Large Professor', 0),
#  ('Prolyphic', 0),
#  ('Rah Swish', 0),
#  ('Oryn the Rebel', 0),
#  ('Redman (rapper)', 0),
#  ('Reks', 0),
#  ('Asher Roth', 0),
#  ('Saigon (rapper)', 0),
#  ('Salt (rapper)', 0),
#  ('Juelz Santana', 0),
#  ('DJ Scratch', 0),
#  ('Erick Sermon', 0),
#  ('Jonathan Shecter', 0),
#  ('Sheff G', 0),
#  ('Beanie Sigel', 0),
#  ('Lil Skies', 0),
#  ('Skinnyfromthe9', 0),
#  ('Slaine (rapper)', 0),
#  ('Will Smith', 0),
#  ('Pop Smoke', 0),
#  ('CL Smooth', 0),
#  ('Sole (hip hop artist)', 0),
#  ('Sonaro', 0),
#  ('Spank Rock', 0),
#  ('Special K (rapper)', 0),
#  ('Jimmy Spicer', 0),
#  ('Spoonie Gee', 0),
#  ('Spose', 0),
#  ('Street Life (rapper)', 0),
#  ('DJ Stretch Armstrong', 0),
#  ('Lil Tecca', 0),
#  ('Sweet Tee', 0),
#  ('Tone Trump', 0),
#  ('Tha Trademarc', 0),
#  ('ASAP Twelvyy', 0),
#  ('U-God', 0),
#  ('Vado (rapper)', 0),
#  ('Ali Vegas', 0),
#  ('Ohmega Watts', 0),
#  ('DJ Webstar', 0),
#  ('Wise (musician)', 0),
#  ('Jimmy Wopo', 0),
#  ('J.R. Writer', 0),
#  ('Young Music DYMG', 0),
#  ('Younglord', 0),
#  ('ZillaKami', 0)]

# %% [markdown]
# # Part B:  Advanced tools
#
# > **Video lecture**: [*Network measures*.](https://www.dropbox.com/scl/fi/8dal16z6z2b7lqhwq2f1j/NetworkMeasures.mp4?rlkey=c0imv3tewun2ivoxgtqrrov31&dl=0) Link: https://www.dropbox.com/scl/fi/8dal16z6z2b7lqhwq2f1j/NetworkMeasures.mp4?rlkey=c0imv3tewun2ivoxgtqrrov31&dl=0

# %% [markdown]
# *Exercise 1:* Last time we visually analyzed (plotted) the degree distributions of our network. Now, let's analyze it using some of the tools from previous lectures. For this exercise we are going to look at the *directed* graph (rememeber, we asked you to keep one?).
#
# >1. What are the average, median, mode, minimum and maximum value of the in-degree? And of the out-degree? How do you intepret the results?
# >    * On top of that, calculate same statistics separately for the network that is spanned only by east-coast rappers and only by west-coast rappers. How do you interpret the results?
# >2. Let's also look at the *[exponent of the degree distribution](http://networksciencebook.com/chapter/4#degree-exponent)*
# >    * To calculate it, you can install `powerlaw` package (I could not install in conda, so I used `pip install powerlaw`)
# >    * Use `powerlaw.Fit(degree).alpha` for fitting
# >    * Find the degree exponent for in-, out- and total- degree distribution. What does it say about our network?
# >    * When analyzing the plots of in- and out- degree distribution last week, did you come up to the same conclusions?
# >    * Some long time ago, couple of scientist have analyzed the network that is spanned by the whole Wikipedia (paper is called [Wikipedias: Collaborative web-based encyclopedias as complex networks](https://journals.aps.org/pre/abstract/10.1103/PhysRevE.74.016115); to access this paper, use findit.dtu.dk or read the preprint on [arXiv](https://arxiv.org/abs/physics/0602149)). Do your findings correspond to the results described in Chapter **III.A**? If not, why?
# >3. Plot a scatter plot of the the in- versus out- degree for all rappers. Comment on the relation between the two.
# >4. Plot a heatmap [(Hint here)](https://stackoverflow.com/questions/2369492/generate-a-heatmap-in-matplotlib-using-a-scatter-data-set) of the the in- versus out- degree for all rappers. What is the advantage of using a heatmap over the scatter plot?
# >5. Why have we used directed graphs throughout this exercise? Could we have used an undirected graph instead?
# >6. We have one more metric that we did not use. The node-attribute `content lenght`. There are two things we can investigate here.
# >   * Firstly, we can verify that more text means more links. If that's true the length should correlate with out-degree.
# >   * Secondly, and more interestingly, it could be that famous rappers have longer texts. And that means more in-links.
# >   * How should you test this? Well, here you are allowed to be **creative**. You may choose the method of your liking to study this question (e.g. look at it visually, test the correlation using spearman or pearson, fit a curve to the data, you decide). Once you've tested, let me know. Are both questions true? If yes, which phenomenon is stronger? Explain your results in your own words.

# %%
# Statistics
#In-degree

in_degree_sequence = [n for d,n in largest_cc.in_degree()]
in_degree_sequence.sort(reverse=True)

print('avg in degree:', np.mean(in_degree_sequence))
print('min in degree:', np.min(in_degree_sequence))
print('max in degree:', np.max(in_degree_sequence))
print('median in degree:', np.median(in_degree_sequence))
print('mode:', statistics.mode(in_degree_sequence))
print()

#Out degree
out_degree_sequence = [n for d,n in largest_cc.out_degree()]
out_degree_sequence.sort(reverse=True)

print('avg out degree:', np.mean(out_degree_sequence))
print('min out degree:', np.min(out_degree_sequence))
print('max out degree:', np.max(out_degree_sequence))
print('median out degree:', np.median(out_degree_sequence))
print('mode:', statistics.mode(out_degree_sequence))
# Out:
# avg in degree: 7.979395604395604
# min in degree: 0
# max in degree: 127
# median in degree: 3.0
# mode: 0
#
# avg out degree: 7.979395604395604
# min out degree: 0
# max out degree: 52
# median out degree: 6.0
# mode: 2

# %%
# same statistics for west 
#In-degree west

W_in_degree_sequence = [n for d,n in W.in_degree()]
W_in_degree_sequence.sort(reverse=True)

print('avg in degree:', np.mean(W_in_degree_sequence))
print('min in degree:', np.min(W_in_degree_sequence))
print('max in degree:', np.max(W_in_degree_sequence))
print('median in degree:', np.median(W_in_degree_sequence))
print('mode:', statistics.mode(W_in_degree_sequence))
print()

#out-degree west

W_out_degree_sequence = [n for d,n in W.out_degree()]
W_out_degree_sequence.sort(reverse=True)

print('avg out degree:', np.mean(W_out_degree_sequence))
print('min out degree:', np.min(W_out_degree_sequence))
print('max out degree:', np.max(W_out_degree_sequence))
print('median out degree:', np.median(W_out_degree_sequence))
print('mode:', statistics.mode(W_out_degree_sequence))
print()

# same statistics for east
#In-degree east

E_in_degree_sequence = [n for d,n in E.in_degree()]
E_in_degree_sequence.sort(reverse=True)

print('avg in degree:', np.mean(E_in_degree_sequence))
print('min in degree:', np.min(E_in_degree_sequence))
print('max in degree:', np.max(E_in_degree_sequence))
print('median in degree:', np.median(E_in_degree_sequence))
print('mode:', statistics.mode(E_in_degree_sequence))
print()

#out-degree east

E_out_degree_sequence = [n for d,n in E.out_degree()]
E_out_degree_sequence.sort(reverse=True)

print('avg out degree:', np.mean(E_out_degree_sequence))
print('min out degree:', np.min(E_out_degree_sequence))
print('max out degree:', np.max(E_out_degree_sequence))
print('median out degree:', np.median(E_out_degree_sequence))
print('mode:', statistics.mode(E_out_degree_sequence))
# Out:
# avg in degree: 5.1826923076923075
# min in degree: 0
# max in degree: 85
# median in degree: 2.0
# mode: 0
#
# avg out degree: 5.1826923076923075
# min out degree: 0
# max out degree: 28
# median out degree: 4.0
# mode: 1
#
# avg in degree: 7.01909307875895
# min in degree: 0
# max in degree: 93
# median in degree: 3.0
# mode: 0
#
# avg out degree: 7.01909307875895
# min out degree: 0
# max out degree: 47
# median out degree: 5.0
# mode: 3

# %% [markdown]
# >2. Let's also look at the *[exponent of the degree distribution](http://networksciencebook.com/chapter/4#degree-exponent)*
# >    * To calculate it, you can install `powerlaw` package (I could not install in conda, so I used `pip install powerlaw`)
# >    * Use `powerlaw.Fit(degree).alpha` for fitting
# >    * Find the degree exponent for in-, out- and total- degree distribution. What does it say about our network?
# >    * When analyzing the plots of in- and out- degree distribution last week, did you come up to the same conclusions?
# >    * Some long time ago, couple of scientist have analyzed the network that is spanned by the whole Wikipedia (paper is called [Wikipedias: Collaborative web-based encyclopedias as complex networks](https://journals.aps.org/pre/abstract/10.1103/PhysRevE.74.016115); to access this paper, use findit.dtu.dk or read the preprint on [arXiv](https://arxiv.org/abs/physics/0602149)). Do your findings correspond to the results described in Chapter **III.A**? If not, why?
#
# > >The article says that out-degree alpha should be around 2.57 and in 2.2. It also says that the out degree does not always follow a powerlaw very well...

# %%
import powerlaw

print(powerlaw.Fit(in_degree_sequence).alpha)
print(powerlaw.Fit(out_degree_sequence).alpha)
print(powerlaw.Fit([n for d,n in nx.to_undirected(largest_cc).degree()]).alpha)
# Out:
# Calculating best minimal value for power law fit
# 2.728424664021232
# Calculating best minimal value for power law fit
# 12.24236893689206
# Calculating best minimal value for power law fit
# 3.524785197915227
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Values less than or equal to 0 in data. Throwing out 0 or negative values

# %% [markdown]
# *Exercise 2:* Centralities, assortativity and more.
#
# Earlier, we found the most connected nodes (using degree centrality). Now let's dig in and try to understand more about the network using more advanced features.
#
# **Note**: Not all of the measures we'll be considering below are defined for directed graphs. Only use the undirected graph when explicitly stated in the exercise.
# >1. Find the 5 most central rappers according to [degree centrality](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.centrality.degree_centrality.html).
# >2. Find the 5 most central rappers according to [betweenness centrality](https://networkx.org/documentation/stable/auto_examples/algorithms/plot_betweenness_centrality.html?highlight=betweenness%20centrality).
# >   * Repeat Exercise A2 or A3 (depending on which visualization method you liked the most). However, this time use betweenness centrality to define the size of the node.
# >   * What role do you imagine rappers with high betweenness centrality play on  Wikipedia?
# >3. Find the 5 most central rappers according to eigenvector centrality. Calculate centrality corresponding to both in- and out-edges (see [NetworkX documentation](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.centrality.eigenvector_centrality.html#networkx.algorithms.centrality.eigenvector_centrality) for details).
# >   * Repeat Exercise A2 or A3 (depending on which visualization method you liked the most). However, this time use eigenvector centrality to define the size of the node.
# >   * What role do you imagine rappers with high wikipedia graph eigenvector centrality play?
# >4. Is the undirected version of the graph assortative with respect to degree? (e.g. do high-degree rappers tend to link to other high-degree rappers, and low-degree rappers to other low-degree rappers?). Provide an interpretation of your answer.
# >5. Is the undirected version of the graph assortative with respect do the `content length` nodal properties? (e.g. do rappers with long Wikipedia pages tend to link to other rappers with long Wiki pages, and *vice versa*?. Hint: Use [this function](https://networkx.github.io/documentation/stable/reference/algorithms/generated/networkx.algorithms.assortativity.attribute_assortativity_coefficient.html#networkx.algorithms.assortativity.attribute_assortativity_coefficient). Provide an interpretation of your answer.
# >6. Is the undirected version of the graph assortative with respect to Coast? (e.g. west-coast rappers tending to link to west-coast rappers, etc.). Provide an interpretation of your answer.
# >7. What is the average shortest path length? Is it similar to the one of a random graph with the same number of nodes $N$  and probablity of connection $p$?
# >   * Take a look at the *distribution* of shortest paths for the two networks (create a histogram for each network) to better compare and contrast. Explain what you see in your own words.

# %% [markdown]
# *Exercise 3*: Is the coast of a rapper important for the network structure? Let us explore if and how it shapes the network (use the undirected network).
# >1. Compute the average node centrality for west-coast and east-coast rappers respectively. You are free to choose your favourite centrality measure or compare different ones. Which coast do the more central rappers have?
# >2. Create a randomized version of the full graph, where the association between nodes and coast is shuffled. Compute the average centrality of west-coast and east-coast rappers for this randomized graph.
# >   * **Hint**: To create this shuffling, simply give everyone a random coast assignment (but with the same number of west-coast and east-coast rappers as in the real data). The way I usually create random lables is by using either [`random.shuffle`](https://docs.python.org/3/library/random.html#random.shuffle) or [`numpy.random.permutation`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.permutation.html).
# >3. Repeat the shuffling process above 1000 times (at least) and plot two histograms, each histogram with the 1000 corresponding average values of centrality obtained for west-coast and east-coast rappers in the shuffeled netowrks.
# >4. Compare the value you have obtained in the real graph, with the randomized cases. Are rappers from one coast more central in the network (on average)?
# >5. Think about your results, what could be possible explanations for what you observe?
#
# The shuffling procedure you just carried out is often called a _permutation test_. It is a super powerful tool that we use all the time. Once you start to think about it, you can answer many questions of the type "Is [property] higher/lower in this network than one might have expected by chance?" with permutation tests.
